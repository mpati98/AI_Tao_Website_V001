# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

driver = webdriver.Chrome()

driver.get("https://hoangthofruits.com/vi/trai-cay-nhap-khau")

title = driver.title

driver.implicitly_wait(0.5)

# text_box = driver.find_element(by=By.NAME, value="my-text")
# submit_button = driver.find_element(by=By.CSS_SELECTOR, value="button")

# text_box.send_keys("Selenium")
# submit_button.click()

message = driver.find_elements(By.TAG_NAME, "img")#.get_attribute("src")
# text = message.text
url_list = []
for item in message:
    url_list.append(item.get_attribute("src"))
driver.quit()

# %%
url_list
# Out:
# ['https://hoangthofruits.com/wp-content/uploads/2023/04/logo-homepage.png',
#  'https://hoangthofruits.com/wp-content/uploads/2023/04/logo-homepage.png',
#  'https://hoangthofruits.com/wp-content/uploads/2023/04/tem2.webp',
#  'https://hoangthofruits.com/wp-content/plugins/translatepress-multilingual/assets/images/flags/en_US.png',
#  'https://hoangthofruits.com/wp-content/uploads/2023/11/left-image-600x450.jpg',
#  'https://hoangthofruits.com/wp-content/uploads/2023/12/Thiet-ke-chua-co-ten.png',
#  'https://hoangthofruits.com/wp-content/uploads/2023/12/Tao-Ambrosia-Gold-4-600x450.png',
#  'https://hoangthofruits.com/wp-content/uploads/2023/12/Tao-Ambrosia-Gold%E2%84%A2.png',
#  'https://hoangthofruits.com/wp-content/uploads/2023/04/Quyt-Uc-1-600x450.png',
#  'https://hoangthofruits.com/wp-content/uploads/2023/04/Quyt-Uc-3.png',
#  'https://hoangthofruits.com/wp-content/uploads/2023/12/z4985799499172_fb50aba65726562a7e615c7b40647574-600x450.jpg',
# ...

# %%
url_list[0].split('/')[-1]
# Out:
# 'logo-homepage.png'

# %%
import requests

    # Define HTTP Headers
headers = {
        "User-Agent": "Chrome/51.0.2704.103",
    }
def download_image(url, file_name, headers):

    # Send GET request
    response = requests.get(url, headers=headers)

    # Save the image
    if response.status_code == 200:
        with open('imgs_data/' + file_name, "wb") as f:
            f.write(response.content)
    else:
        print(response.status_code)

# %%
img_url
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 img_url
#
# NameError: name 'img_url' is not defined

# %%
import random
for img_url in url_list[0:66]:
    num = random.random()
    file_name =str(num) + img_url.split('/')[-1] 
    download_image(img_url, file_name, headers=headers)

# %%
urls = []
for url in data["urls"]:
    urls.append(url.replace("https://www.hotcoursesabroad.com/", "https://www.hotcourses.vn/"))
urls
# Out:
# ['https://www.hotcourses.vn/study/australia/school-college-university/the-university-of-melbourne/879/international.html#flpod',
#  'https://www.hotcourses.vn/study/australia/school-college-university/university-of-sydney/72239/international.html#flpod',
#  'https://www.hotcourses.vn/study/australia/school-college-university/unsw-sydney-university-of-new-south-wales/72233/international.html#flpod',
#  'https://www.hotcourses.vn/study/australia/school-college-university/the-university-of-adelaide/72228/international.html#flpod',
#  'https://www.hotcourses.vn/study/australia/school-college-university/curtin-university/72214/international.html#flpod',
#  'https://www.hotcourses.vn/study/australia/school-college-university/university-of-western-australia/888/international.html#flpod',
#  'https://www.hotcourses.vn/study/australia/school-college-university/deakin-university/72215/international.html#flpod',
# ...

# %%
type(urls)
# Out:
# list

# %%
import csv
with open('schools_url_vn.csv', 'w', newline='') as file:
    # Step 4: Using csv.writer to write the list to the CSV file
    writer = csv.writer(file)
    writer.writerow(urls)

# %%
urls_data = pd.read_csv('schools_url_vn.csv', delimiter=',')
urls_data.head()
# Out:
# Empty DataFrame
# ...

# %%
urls_data = urls_data.transpose()

# %%
urls_data.to_csv('urls_vn.csv')

# %%
from openai import OpenAI
client = OpenAI(api_key='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')

completion = client.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[  
    {"role": "system", "content": "Từ tên trường đã co, trả lời các câu hỏi: 1. Trường xếp hạng mấy? 2. Trường có các ngành gì nổi bậc? 3. Trường ở thành phố nào? 4. Mô tả chi tiết về trường?(Tọa lạc tại thành phố/bang, Xếp hạng của trường trên các BXH uy tín(QS, THE), Số lượng các ngành học và chương trình đào tạo, Chất lượng giảng dạy, Cơ sở vật chất, Mức độ hài lòng của sinh viên sau tốt nghiệp) 5. Trường có đặc điểm gì nổi bậc? (Địa điểm campus, Xếp hạng, 1-3 điểm nổi bật nhất của trường)"},
    {"role": "user", "content": "The University of Sydney"}
  ]
)
response_list = completion.choices
response = completion.choices[0].message.content
print(completion.choices[0].message.content)
# Out:
# 1. Trường xếp hạng mấy?
# Trường Đại học Sydney nằm trong top 50 trường đại học hàng đầu thế giới, được xếp hạng 40 trên bảng xếp hạng QS World University Rankings 2022.
#
# 2. Trường có các ngành gì nổi bậc?
# Trường Đại học Sydney có nhiều ngành nổi bật như Khoa kinh tế, Khoa luật, Y khoa, Kỹ thuật và Công nghệ, Khoa học xã hội, Ngôn ngữ học và Văn học, Nghiên cứu y học, Nghiên cứu khoa học và công nghệ, Nghệ thuật và Xã hội...
#
# 3. Trường ở thành phố nào?
# Trường Đại học Sydney nằm ở thành phố Sydney, bang New South Wales, Úc.
#
# 4. Mô tả chi tiết về trường:
# - Tọa lạc tại thành phố Sydney, bang New South Wales, Đại học Sydney là một trong những trường đại học cổ nhất và đáng chú ý nhất của Úc. Trường có một trong những cơ sở vật chất tốt nhất và điểm nổi bật của trường là aisticalib campus nằm tại trung tâm thành phố Sydney.
# ...

# %%
rs = response.split('\n\n')
rs
# Out:
# ['1. The University of Sydney được xếp hạng 42 trong danh sách các trường đại học hàng đầu thế giới năm 2020 theo QS World University Rankings.',
#  '2. Trường có nhiều ngành nổi bật như Khoa học, Kỹ thuật, Y học, Quản lý, Luật, Nhân văn và Xã hội.',
#  '3. Trường có trụ sở tại thành phố Sydney, New South Wales, Australia.',
#  '4. Đại học Sydney là trường đại học công lập lâu đời nhất ở Australia, được thành lập năm 1850. Trường có hơn 70.000 sinh viên và nổi tiếng với nền giáo dục chất lượng cao, môi trường học tập truyền thống và cơ sở vật chất hiện đại.',
#  '5. Đặc điểm nổi bật của trường bao gồm sự đa dạng và chất lượng của các ngành học, lượng nghiên cứu và cống hiến cho cộng đồng, cũng như quy mô toàn cầu và tầm ảnh hưởng của mình trong lĩnh vực giáo dục và nghiên cứu. Trường cũng có một mạng lưới rộng lớn các đối tác và liên kết toàn cầu, mang lại cho sinh viên nhiều cơ hội học tập và trải nghiệm quốc tế.']

# %%
rs_cf = []
for item in rs:
    rs_cf.append(item[3:])
rs_cf
# Out:
# ['The University of Sydney được xếp hạng 42 trong danh sách các trường đại học hàng đầu thế giới năm 2020 theo QS World University Rankings.',
#  'Trường có nhiều ngành nổi bật như Khoa học, Kỹ thuật, Y học, Quản lý, Luật, Nhân văn và Xã hội.',
#  'Trường có trụ sở tại thành phố Sydney, New South Wales, Australia.',
#  'Đại học Sydney là trường đại học công lập lâu đời nhất ở Australia, được thành lập năm 1850. Trường có hơn 70.000 sinh viên và nổi tiếng với nền giáo dục chất lượng cao, môi trường học tập truyền thống và cơ sở vật chất hiện đại.',
#  'Đặc điểm nổi bật của trường bao gồm sự đa dạng và chất lượng của các ngành học, lượng nghiên cứu và cống hiến cho cộng đồng, cũng như quy mô toàn cầu và tầm ảnh hưởng của mình trong lĩnh vực giáo dục và nghiên cứu. Trường cũng có một mạng lưới rộng lớn các đối tác và liên kết toàn cầu, mang lại cho sinh viên nhiều cơ hội học tập và trải nghiệm quốc tế.']

# %%
list_rs = []
list_rs.append(rs_cf)

# %%
list_rs.append(rs_cf)
list_rs
# Out:
# [['The University of Sydney được xếp hạng 42 trong danh sách các trường đại học hàng đầu thế giới năm 2020 theo QS World University Rankings.',
#   'Trường có nhiều ngành nổi bật như Khoa học, Kỹ thuật, Y học, Quản lý, Luật, Nhân văn và Xã hội.',
#   'Trường có trụ sở tại thành phố Sydney, New South Wales, Australia.',
#   'Đại học Sydney là trường đại học công lập lâu đời nhất ở Australia, được thành lập năm 1850. Trường có hơn 70.000 sinh viên và nổi tiếng với nền giáo dục chất lượng cao, môi trường học tập truyền thống và cơ sở vật chất hiện đại.',
#   'Đặc điểm nổi bật của trường bao gồm sự đa dạng và chất lượng của các ngành học, lượng nghiên cứu và cống hiến cho cộng đồng, cũng như quy mô toàn cầu và tầm ảnh hưởng của mình trong lĩnh vực giáo dục và nghiên cứu. Trường cũng có một mạng lưới rộng lớn các đối tác và liên kết toàn cầu, mang lại cho sinh viên nhiều cơ hội học tập và trải nghiệm quốc tế.'],
# ...

# %%
len(list_rs)
# Out:
# 2

# %%
import pandas as pd

# create a list of lists
# lst = [
#     ['tom', 'reacher', 25],
#     ['krish', 'pete', 30],
#     ['nick', 'wilson', 26],
#     ['juli', 'williams', 22]
# ]

# create a DataFrame from the list
df = pd.DataFrame(list_rs, columns=['row_1', 'row_2', '_row_3', 'row_4', '_row_5'])

# print the DataFrame
print(df)
# Out:
#                                                row_1  \
# 0  The University of Sydney được xếp hạng 42 tron...
# 1  The University of Sydney được xếp hạng 42 tron...
#
#                                                row_2  \
# 0  Trường có nhiều ngành nổi bật như Khoa học, Kỹ...
# 1  Trường có nhiều ngành nổi bật như Khoa học, Kỹ...
#
#                                               _row_3  \
# 0  Trường có trụ sở tại thành phố Sydney, New Sou...
# 1  Trường có trụ sở tại thành phố Sydney, New Sou...
#
#                                                row_4  \
# 0  Đại học Sydney là trường đại học công lập lâu ...
# 1  Đại học Sydney là trường đại học công lập lâu ...
#
#                                               _row_5
# 0  Đặc điểm nổi bật của trường bao gồm sự đa dạng...
# 1  Đặc điểm nổi bật của trường bao gồm sự đa dạng...

# %%
df.to_csv('list_test.csv')

# %%
import pandas as pd

school_data = pd.read_csv('uni_description.csv')
school_data.head()
# Out:
#                                     uni_name  \
# 0                the-university-of-melbourne
# 1                       university-of-sydney
# 2  unsw-sydney-university-of-new-south-wales
# 3                 the-university-of-adelaide
# 4                          curtin-university
#
#                                             contents  \
# 0  With a proud history of innovation and forward...
# 1   The University Of Sydney, New South Wales, Au...
# 2  UNSW Sydney (University of New South Wales) is...
# 3   University Of Adelaide, South Australia, Aust...
# 4  Curtin University is an innovative, global uni...
#
#                                          aug_content  uni_name_length  \
# 0  With a proud history of innovation and forward...               27
# 1  The University Of Sydney, New South Wales, Aus...               20
# 2  UNSW Sydney (University of New South Wales) is...               41
# 3  University Of Adelaide, South Australia, Austr...               26
# ...

# %%
school_data['uni_name'] = [item.replace('-', ' ').title() for item in school_data['uni_name'].values]
school_data.head()
# Out:
#                                     uni_name  \
# 0                The University Of Melbourne
# 1                       University Of Sydney
# 2  Unsw Sydney University Of New South Wales
# 3                 The University Of Adelaide
# 4                          Curtin University
#
#                                             contents  \
# 0  With a proud history of innovation and forward...
# 1   The University Of Sydney, New South Wales, Au...
# 2  UNSW Sydney (University of New South Wales) is...
# 3   University Of Adelaide, South Australia, Aust...
# 4  Curtin University is an innovative, global uni...
#
#                                          aug_content  uni_name_length  \
# 0  With a proud history of innovation and forward...               27
# 1  The University Of Sydney, New South Wales, Aus...               20
# 2  UNSW Sydney (University of New South Wales) is...               41
# 3  University Of Adelaide, South Australia, Austr...               26
# ...

# %%
school_data.shape
# Out:
# (401, 5)

# %%
df3 = pd.merge(df, school_data, left_on='team', right_on='team_name')
